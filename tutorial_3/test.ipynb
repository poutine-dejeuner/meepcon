# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import smooth_image

# %%
x0 = np.random.rand(101,91)
x0 = smooth_image(x0, 10)
print(x0.min(), x0.max())
x0 = (x0 - x0.min())/(x0.max()-x0.min())
print(x0.min(), x0.max())
plt.imshow(x0)
plt.show()
plt.imshow(x0, vmin=0, vmax=1)
plt.show()
# Out:
# 0.4631225524347415 0.5252554747463186
# 0.0 1.0
